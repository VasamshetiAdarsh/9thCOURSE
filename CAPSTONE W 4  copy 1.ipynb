# %%
## Week 5 Project

# %%
# !pip install beautifulsoup4
# !pip install lxml
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 

javascript:void(0);
from IPython.display import display_html
import pandas as pd
import numpy as np
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
from bs4 import BeautifulSoup
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.6.20  |       hecda079_0         145 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_1         2.1 MB  conda-forge
#     certifi-2020.6.20          |   py36h9f0ad1d_0         151 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
# ...

# %%
# Get longitude and latitude for Toronto
address = 'mumbai , mumbai'

geolocator = Nominatim(user_agent="mumbai_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of mumbai is {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of mumbai is 18.9387711, 72.8353355.

# %%
# Set up Foursquare
CLIENT_ID = 'W1T51HJBLTFBUZDEYA3KWJCSEVUMR5AKPD2SPO1WHZQH02TF' # your Foursquare ID
CLIENT_SECRET = 'JSFMQA04HEISC2P1CSEIQV1R5PES1WIWMDKKQ4KI02MGOIJ5' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: W1T51HJBLTFBUZDEYA3KWJCSEVUMR5AKPD2SPO1WHZQH02TF
# CLIENT_SECRET:JSFMQA04HEISC2P1CSEIQV1R5PES1WIWMDKKQ4KI02MGOIJ5

# %%
search_query = 'Restaurant'
radius = 50000
print(search_query + ' .... OK!')
# Out:
# Restaurant .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=W1T51HJBLTFBUZDEYA3KWJCSEVUMR5AKPD2SPO1WHZQH02TF&client_secret=JSFMQA04HEISC2P1CSEIQV1R5PES1WIWMDKKQ4KI02MGOIJ5&ll=18.9387711,72.8353355&v=20180605&query=Restaurant&radius=50000&limit=100'

# %%
results = requests.get(url).json()

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 1  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...    False
# 2  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 3  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 4  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
#
#                          id             location.address location.cc  \
# 0  5263f0f5498edc1ad5f3270f           Near GPO, Fort, VT          IN
# 1  4e4c0a4122713bd908c641ff                 Opposite GPO          IN
# 2  4fb5276be4b0b34b9ac27a1b  Palton Road, Near Haj House          IN
# 3  4d9f2bfe9b91a1cda6c365c0                      Opp CST          IN
# 4  4c09449eed2595217aee1256            Veer Nariman Road          IN
#
#   location.city location.country                location.crossStreet  \
# 0        Mumbai            India                S. Bhagat Singh Road
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                                 name         categories  \
# 0  Nanumal Bhojraj Restaurant - Fort  Indian Restaurant
# 1                 Farhang Restaurant         Steakhouse
# 2               Iran Like Restaurant  Indian Restaurant
# 3            New Majestic Restaurant  Indian Restaurant
# 4        Stadium Restaurant & Stores  Indian Restaurant
#
#                        address  cc    city country  \
# 0           Near GPO, Fort, VT  IN  Mumbai   India
# 1                 Opposite GPO  IN  Mumbai   India
# 2  Palton Road, Near Haj House  IN  Mumbai   India
# 3                      Opp CST  IN  Mumbai   India
# 4            Veer Nariman Road  IN  Mumbai   India
#
#                           crossStreet  distance  \
# 0                S. Bhagat Singh Road       260
# 1                      Ballard Estate       280
# 2                                 NaN       747
# 3                                 NaN        29
# 4  Next to Vodafone Store, Churchgate      1082
#
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
search_query = 'Office'
radius = 50000
print(search_query + ' .... OK!')
# Out:
# Office .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=W1T51HJBLTFBUZDEYA3KWJCSEVUMR5AKPD2SPO1WHZQH02TF&client_secret=JSFMQA04HEISC2P1CSEIQV1R5PES1WIWMDKKQ4KI02MGOIJ5&ll=18.9387711,72.8353355&v=20180605&query=Office&radius=50000&limit=100'

# %%
results = requests.get(url).json()

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d126941735', 'name': 'G...    False
# 1  [{'id': '4bf58dd8d48988d12e941735', 'name': 'P...    False
# 2  [{'id': '52e81612bcbc57f1066b7a36', 'name': 'W...    False
# 3                                                 []    False
# 4                                                 []    False
#
#                          id  \
# 0  4c905a27de3d236a3c446b18
# 1  51791fafe4b0d062da09ed68
# 2  57d8dc43cd100b84fde9d335
# 3  4c33179a213c2d7f7452365d
# 4  4d87744f651041bdc74f9b30
#
#                                     location.address location.cc  \
# 0                          Shaheed Bhagat Singh Road          IN
# 1                   Opposite : CST Station Main Gate          IN
# 2                22-A Jagjeevan Mansion Ground Floor          IN
# 3                        Mittal tower b Naiman point          IN
# 4  B1  Amarchand Mansion  Ground Floor  Madam Cam...          IN
#
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                             name           categories                address  \
# 0   Logitech office trade center      Campaign Office                    NaN
# 1              Kurla Post Office          Post Office                    NaN
# 2   "L" Ward Office, Kurla West.  Government Building                    NaN
# 3                         Office                 None          Chandrapushpa
# 4  M Ward Office Chembur Station               Office  MCGM, Chembur Station
#
#    cc    city country crossStreet  distance  \
# 0  IN     NaN   India         NaN        27
# 1  IN  Mumbai   India         NaN       309
# 2  IN     NaN   India         NaN       614
# 3  IN  Mumbai   India     HD Road      1666
# 4  IN  Mumbai   India         NaN      2678
#
#                                     formattedAddress  \
# 0                                            [India]
# 1                       [Mumbai, Mahārāshtra, India]
# 2                                            [India]
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=14
                       ) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='orange',
        popup=label,
        fill = True,
        fill_color='orange',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
dataframe_filtered.shape
# Out:
# (50, 15)

# %%
dataframe_filtered.dtypes
# Out:
# name                 object
# categories           object
# address              object
# cc                   object
# city                 object
# country              object
# crossStreet          object
# distance              int64
# formattedAddress     object
# labeledLatLngs       object
# lat                 float64
# lng                 float64
# postalCode           object
# state                object
# id                   object
# dtype: object

# %%
dataframe_filtered.lat
# Out:
# 0     19.075981
# 1     19.073605
# 2     19.070849
# 3     19.068907
# 4     19.061681
# 5     19.081749
# 6     19.064748
# 7     19.075361
# 8     19.073421
# 9     19.070844
# 10    19.070550
# 11    19.073292
# 12    19.074740
# 13    19.108018
# 14    19.108393
# 15    19.077116
# 16    19.068857
# 17    19.071911
# 18    19.077521
# 19    19.071411
# 20    19.069309
# 21    19.112548
# 22    19.177378
# 23    19.063189
# 24    19.086692
# 25    19.060426
# 26    19.085962
# 27    19.073361
# 28    19.060901
# 29    19.085828
# 30    19.113908
# 31    19.065010
# 32    19.081533
# 33    19.059499
# 34    19.081848
# 35    19.094756
# 36    19.064623
# 37    19.095355
# 38    19.081660
# 39    19.056940
# 40    19.058485
# 41    19.135656
# 42    19.060578
# 43    19.061391
# 44    19.064741
# 45    19.078559
# 46    19.082436
# 47    19.063050
# 48    19.063029
# 49    19.142007
# Name: lat, dtype: float64

# %%
dataframe_filtered.lng
# Out:
# 0     72.837663
# 1     72.837917
# 2     72.836809
# 3     72.835517
# 4     72.826929
# 5     72.826820
# 6     72.835073
# 7     72.835707
# 8     72.837577
# 9     72.834495
# 10    72.836157
# 11    72.831004
# 12    72.837764
# 13    72.837606
# 14    72.831005
# 15    72.837586
# 16    72.834426
# 17    72.837525
# 18    72.836896
# 19    72.844015
# 20    72.837357
# 21    72.819690
# 22    72.833687
# 23    72.836941
# 24    72.833791
# 25    72.830032
# 26    72.837240
# 27    72.833734
# 28    72.833605
# 29    72.831328
# 30    72.834305
# 31    72.812281
# 32    72.833440
# 33    72.828679
# 34    72.833884
# 35    72.831855
# 36    72.833336
# 37    72.827485
# 38    72.830874
# 39    72.834836
# 40    72.834270
# 41    72.830041
# 42    72.829435
# 43    72.835561
# 44    72.829118
# 45    72.835495
# 46    72.828532
# 47    72.827185
# 48    72.835886
# 49    72.831985
# Name: lng, dtype: float64

# %%
dataframe_filtered.distance
# Out:
# 0        27
# 1       309
# 2       614
# 3      1666
# 4      2678
# 5      1005
# 6      1890
# 7      2713
# 8       658
# 9       643
# 10      637
# 11      710
# 12     2923
# 13     3627
# 14     4418
# 15     1199
# 16     1238
# 17     1240
# 18     1379
# 19     1389
# 20     1458
# 21     4399
# 22    11301
# 23     1662
# 24     1703
# 25     1756
# 26     1770
# 27     1800
# 28     1819
# 29     1587
# 30     5604
# 31     1903
# 32     1894
# 33     2334
# 34     2061
# 35     2108
# 36     2149
# 37     2158
# 38     2213
# 39     3037
# 40     3416
# 41     7699
# 42     2200
# 43     2229
# 44     2128
# 45     2330
# 46     2248
# 47     2287
# 48     2316
# 49     9515
# Name: distance, dtype: int64

# %%
k=3
dataframe_filtered = dataframe_filtered.drop(['postalCode','city','country','name','categories','address','cc','crossStreet','formattedAddress','labeledLatLngs','state','id'],1)
kmeans = KMeans(n_clusters = k,random_state=0).fit(dataframe_filtered)
kmeans.labels_
dataframe_filtered.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
# create map
map_clusters = folium.Map(location=[19.0759899, 72.8773928],zoom_start=10)

# set color scheme for the clusters
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lng, neighbourhood, cluster in zip(dataframe_filtered['lat'], dataframe_filtered['lng'], dataframe_filtered['distance'], dataframe_filtered['Cluster Labels']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [raw]
# ## As Mumbai is densly populated , We settle on 3 clusters , the central mumbai with red dotted are highly poulated regions with both office and resturnts , any new startup will have good oppertunity in this cluster region .

# %% [markdown]
# ## Thanks
