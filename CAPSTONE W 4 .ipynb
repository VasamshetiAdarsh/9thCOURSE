# %% [markdown]
# ## Week 4 Project

# %%
# !pip install beautifulsoup4
# !pip install lxml
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 


from IPython.display import display_html
import pandas as pd
import numpy as np
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
from bs4 import BeautifulSoup
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors

print('Folium installed')
print('Libraries imported.')
# Out:
# Requirement already satisfied: beautifulsoup4 in /opt/conda/envs/Python36/lib/python3.6/site-packages (4.7.1)
# Requirement already satisfied: soupsieve>=1.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from beautifulsoup4) (1.7.1)
# Requirement already satisfied: lxml in /opt/conda/envs/Python36/lib/python3.6/site-packages (4.3.1)
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2020.6.20          |   py36h9f0ad1d_0         151 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ca-certificates-2020.6.20  |       hecda079_0         145 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_1         2.1 MB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          4.1.0-py_1        conda-forge
#     branca:          0.4.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     python_abi:      3.6-1_cp36m       conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     certifi:         2020.6.20-py36_0              --> 2020.6.20-py36h9f0ad1d_0 conda-forge
#     openssl:         1.1.1g-h7b6447c_0             --> 1.1.1g-h516909a_1        conda-forge
#
# The following packages will be DOWNGRADED:
#
#     ca-certificates: 2020.6.24-0                   --> 2020.6.20-hecda079_0     conda-forge
#
#
# Downloading and Extracting Packages
# certifi-2020.6.20    | 151 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# ca-certificates-2020 | 145 KB    | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %%
# Get longitude and latitude for Toronto
address = 'mumbai , mumbai'

geolocator = Nominatim(user_agent="mumbai_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of mumbai is {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of mumbai is 19.0759899, 72.8773928.

# %%
# Set up Foursquare
CLIENT_ID = 'W1T51HJBLTFBUZDEYA3KWJCSEVUMR5AKPD2SPO1WHZQH02TF' # your Foursquare ID
CLIENT_SECRET = 'JSFMQA04HEISC2P1CSEIQV1R5PES1WIWMDKKQ4KI02MGOIJ5' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: W1T51HJBLTFBUZDEYA3KWJCSEVUMR5AKPD2SPO1WHZQH02TF
# CLIENT_SECRET:JSFMQA04HEISC2P1CSEIQV1R5PES1WIWMDKKQ4KI02MGOIJ5

# %%
search_query = 'Restaurant'
radius = 50000
print(search_query + ' .... OK!')
# Out:
# Restaurant .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=W1T51HJBLTFBUZDEYA3KWJCSEVUMR5AKPD2SPO1WHZQH02TF&client_secret=JSFMQA04HEISC2P1CSEIQV1R5PES1WIWMDKKQ4KI02MGOIJ5&ll=19.0759899,72.8773928&v=20180605&query=Restaurant&radius=50000&limit=100'

# %%
results = requests.get(url).json()

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...    False
# 1  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...    False
# 2  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 3  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 4  [{'id': '54135bf5e4b08f3d2429dff4', 'name': 'M...    False
#
#                          id                           location.address  \
# 0  4d4be7dce1ec6dcb0874d275                                        NaN
# 1  4ffff479e4b0da072a4c510e  Ostwal orbit,shop no 2\3,Kanakia junction
# 2  511776a6e4b0c785a054bc7b                                        NaN
# 3  4dc6a998b0fb5556cd0e99a2                       Above Shoppers' Stop
# 4  4e4d68fb88775b38b2161f5e                                 Kurla west
#
#   location.cc location.city location.country  \
# 0          IN        Mumbai            India
# 1          IN        Mumbai            India
# 2          IN           NaN            India
# 3          IN        Mumbai            India
# 4          IN        Mumbai            India
#
#                   location.crossStreet  location.distance  \
# 0                                  NaN                820
# 1                  Mira bhayandar road                 27
# 2                                  NaN                 90
# 3  Near Amar Mahal, Chembur- Ghatkopar               2534
# 4                               LBS Rd                489
#
#                            location.formattedAddress  \
# 0                       [Mumbai, Mahārāshtra, India]
# 1  [Ostwal orbit,shop no 2\3,Kanakia junction (Mi...
# 2                                            [India]
# 3  [Above Shoppers' Stop (Near Amar Mahal, Chembu...
# 4  [Kurla west (LBS Rd), Mumbai 400070, Mahārāsht...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 19.07463444538323...     19.074634
# 1  [{'label': 'display', 'lat': 19.0759837, 'lng'...     19.075984
# 2  [{'label': 'display', 'lat': 19.07670593261718...     19.076706
# 3  [{'label': 'display', 'lat': 19.06966328826220...     19.069663
# 4  [{'label': 'display', 'lat': 19.07953178124444...     19.079532
#
#    location.lng location.postalCode location.state                       name  \
# 0     72.869724                 NaN    Mahārāshtra    Mahesh Restaurant & Bar
# 1     72.877656                 NaN    Mahārāshtra          Subway restaurant
# 2     72.877808                 NaN            NaN   jhakas Family Restaurant
# 3     72.900535              400089    Mahārāshtra  IVY Restaurant & Banquets
# 4     72.880152              400070    Mahārāshtra          Sahara Restaurant
#
#      referralId venuePage.id
# 0  v-1596471693          NaN
# 1  v-1596471693          NaN
# 2  v-1596471693          NaN
# 3  v-1596471693     72795032
# 4  v-1596471693          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                         name          categories  \
# 0    Mahesh Restaurant & Bar                 Bar
# 1          Subway restaurant      Sandwich Place
# 2   jhakas Family Restaurant   Indian Restaurant
# 3  IVY Restaurant & Banquets          Restaurant
# 4          Sahara Restaurant  Mughlai Restaurant
#
#                                      address  cc    city country  \
# 0                                        NaN  IN  Mumbai   India
# 1  Ostwal orbit,shop no 2\3,Kanakia junction  IN  Mumbai   India
# 2                                        NaN  IN     NaN   India
# 3                       Above Shoppers' Stop  IN  Mumbai   India
# 4                                 Kurla west  IN  Mumbai   India
#
#                            crossStreet  distance  \
# 0                                  NaN       820
# 1                  Mira bhayandar road        27
# 2                                  NaN        90
# 3  Near Amar Mahal, Chembur- Ghatkopar      2534
# 4                               LBS Rd       489
#
#                                     formattedAddress  \
# 0                       [Mumbai, Mahārāshtra, India]
# 1  [Ostwal orbit,shop no 2\3,Kanakia junction (Mi...
# 2                                            [India]
# 3  [Above Shoppers' Stop (Near Amar Mahal, Chembu...
# 4  [Kurla west (LBS Rd), Mumbai 400070, Mahārāsht...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 19.07463444538323...  19.074634  72.869724
# 1  [{'label': 'display', 'lat': 19.0759837, 'lng'...  19.075984  72.877656
# 2  [{'label': 'display', 'lat': 19.07670593261718...  19.076706  72.877808
# 3  [{'label': 'display', 'lat': 19.06966328826220...  19.069663  72.900535
# 4  [{'label': 'display', 'lat': 19.07953178124444...  19.079532  72.880152
#
#   postalCode        state                        id
# 0        NaN  Mahārāshtra  4d4be7dce1ec6dcb0874d275
# 1        NaN  Mahārāshtra  4ffff479e4b0da072a4c510e
# 2        NaN          NaN  511776a6e4b0c785a054bc7b
# 3     400089  Mahārāshtra  4dc6a998b0fb5556cd0e99a2
# 4     400070  Mahārāshtra  4e4d68fb88775b38b2161f5e

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
search_query = 'Office'
radius = 50000
print(search_query + ' .... OK!')
# Out:
# Office .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=W1T51HJBLTFBUZDEYA3KWJCSEVUMR5AKPD2SPO1WHZQH02TF&client_secret=JSFMQA04HEISC2P1CSEIQV1R5PES1WIWMDKKQ4KI02MGOIJ5&ll=19.0759899,72.8773928&v=20180605&query=Office&radius=50000&limit=100'

# %%
results = requests.get(url).json()

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '5032764e91d4c4b30a586d5a', 'name': 'C...    False
# 1  [{'id': '4bf58dd8d48988d172941735', 'name': 'P...    False
# 2  [{'id': '4bf58dd8d48988d126941735', 'name': 'G...    False
# 3                                                 []    False
# 4  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
#
#                          id       location.address location.cc location.city  \
# 0  53a2ba15498e11c1732c81a3                    NaN          IN           NaN
# 1  522ae27211d23abba41a0045                    NaN          IN        Mumbai
# 2  5191c30e498ef53d154ea579                    NaN          IN           NaN
# 3  4c36c4d70a71c9b60dc23dc9          Chandrapushpa          IN        Mumbai
# 4  4d2585a1903c8cfaa006cf25  MCGM, Chembur Station          IN        Mumbai
#
#   location.country location.crossStreet  location.distance  \
# 0            India                  NaN                 27
# 1            India                  NaN                309
# 2            India                  NaN                614
# 3            India              HD Road               1666
# 4            India                  NaN               2678
#
#                            location.formattedAddress  \
# 0                                            [India]
# 1                       [Mumbai, Mahārāshtra, India]
# 2                                            [India]
# 3  [Chandrapushpa (HD Road), Mumbai 400086, Mahār...
# 4  [MCGM, Chembur Station, Mumbai, Mahārāshtra, I...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 19.07598139540013...     19.075981
# 1  [{'label': 'display', 'lat': 19.07360458374023...     19.073605
# 2  [{'label': 'display', 'lat': 19.07084865356027...     19.070849
# 3  [{'label': 'display', 'lat': 19.068907, 'lng':...     19.068907
# 4  [{'label': 'display', 'lat': 19.06168062847358...     19.061681
#
#    location.lng location.postalCode location.state  \
# 0     72.877656                 NaN            NaN
# 1     72.875877                 NaN    Mahārāshtra
# 2     72.879520                 NaN            NaN
# 3     72.891345              400086    Mahārāshtra
# 4     72.897864                 NaN    Mahārāshtra
#
#                             name    referralId
# 0   Logitech office trade center  v-1596471697
# 1              Kurla Post Office  v-1596471697
# 2   "L" Ward Office, Kurla West.  v-1596471697
# 3                         Office  v-1596471697
# 4  M Ward Office Chembur Station  v-1596471697

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                             name           categories                address  \
# 0   Logitech office trade center      Campaign Office                    NaN
# 1              Kurla Post Office          Post Office                    NaN
# 2   "L" Ward Office, Kurla West.  Government Building                    NaN
# 3                         Office                 None          Chandrapushpa
# 4  M Ward Office Chembur Station               Office  MCGM, Chembur Station
#
#    cc    city country crossStreet  distance  \
# 0  IN     NaN   India         NaN        27
# 1  IN  Mumbai   India         NaN       309
# 2  IN     NaN   India         NaN       614
# 3  IN  Mumbai   India     HD Road      1666
# 4  IN  Mumbai   India         NaN      2678
#
#                                     formattedAddress  \
# 0                                            [India]
# 1                       [Mumbai, Mahārāshtra, India]
# 2                                            [India]
# 3  [Chandrapushpa (HD Road), Mumbai 400086, Mahār...
# 4  [MCGM, Chembur Station, Mumbai, Mahārāshtra, I...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 19.07598139540013...  19.075981  72.877656
# 1  [{'label': 'display', 'lat': 19.07360458374023...  19.073605  72.875877
# 2  [{'label': 'display', 'lat': 19.07084865356027...  19.070849  72.879520
# 3  [{'label': 'display', 'lat': 19.068907, 'lng':...  19.068907  72.891345
# 4  [{'label': 'display', 'lat': 19.06168062847358...  19.061681  72.897864
#
#   postalCode        state                        id
# 0        NaN          NaN  53a2ba15498e11c1732c81a3
# 1        NaN  Mahārāshtra  522ae27211d23abba41a0045
# 2        NaN          NaN  5191c30e498ef53d154ea579
# 3     400086  Mahārāshtra  4c36c4d70a71c9b60dc23dc9
# 4        NaN  Mahārāshtra  4d2585a1903c8cfaa006cf25

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=14
                       ) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='orange',
        popup=label,
        fill = True,
        fill_color='orange',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
dataframe_filtered.shape
# Out:
# (50, 15)

# %%
dataframe_filtered.dtypes
# Out:
# name                 object
# categories           object
# address              object
# cc                   object
# city                 object
# country              object
# crossStreet          object
# distance              int64
# formattedAddress     object
# labeledLatLngs       object
# lat                 float64
# lng                 float64
# postalCode           object
# state                object
# id                   object
# dtype: object

# %%
dataframe_filtered.lat
# Out:
# 0     19.075981
# 1     19.073605
# 2     19.070849
# 3     19.068907
# 4     19.061681
# 5     19.081749
# 6     19.064748
# 7     19.075361
# 8     19.073421
# 9     19.070844
# 10    19.070550
# 11    19.073292
# 12    19.074740
# 13    19.108018
# 14    19.108393
# 15    19.077116
# 16    19.068857
# 17    19.071911
# 18    19.077521
# 19    19.071411
# 20    19.069309
# 21    19.112548
# 22    19.177378
# 23    19.063189
# 24    19.086692
# 25    19.060426
# 26    19.085962
# 27    19.073361
# 28    19.060901
# 29    19.085828
# 30    19.113908
# 31    19.065010
# 32    19.081533
# 33    19.059499
# 34    19.081848
# 35    19.094756
# 36    19.064623
# 37    19.095355
# 38    19.081660
# 39    19.056940
# 40    19.058485
# 41    19.135656
# 42    19.060578
# 43    19.061391
# 44    19.064741
# 45    19.078559
# 46    19.082436
# 47    19.063050
# 48    19.063029
# 49    19.142007
# Name: lat, dtype: float64

# %%
dataframe_filtered.lng
# Out:
# 0     72.877656
# 1     72.875877
# 2     72.879520
# 3     72.891345
# 4     72.897864
# 5     72.884760
# 6     72.863924
# 7     72.851608
# 8     72.871755
# 9     72.874609
# 10    72.879300
# 11    72.871276
# 12    72.905150
# 13    72.883740
# 14    72.853131
# 15    72.888734
# 16    72.868361
# 17    72.866424
# 18    72.864382
# 19    72.865105
# 20    72.865467
# 21    72.861493
# 22    72.882916
# 23    72.869250
# 24    72.888963
# 25    72.880129
# 26    72.890498
# 27    72.860510
# 28    72.884048
# 29    72.888323
# 30    72.842339
# 31    72.863520
# 32    72.894420
# 33    72.891097
# 34    72.858803
# 35    72.874705
# 36    72.860874
# 37    72.876284
# 38    72.897560
# 39    72.898056
# 40    72.904065
# 41    72.914414
# 42    72.864289
# 43    72.862882
# 44    72.861030
# 45    72.855411
# 46    72.857141
# 47    72.860499
# 48    72.860167
# 49    72.934854
# Name: lng, dtype: float64

# %%
dataframe_filtered.distance
# Out:
# 0        27
# 1       309
# 2       614
# 3      1666
# 4      2678
# 5      1005
# 6      1890
# 7      2713
# 8       658
# 9       643
# 10      637
# 11      710
# 12     2923
# 13     3627
# 14     4418
# 15     1199
# 16     1238
# 17     1240
# 18     1379
# 19     1389
# 20     1458
# 21     4399
# 22    11301
# 23     1662
# 24     1703
# 25     1756
# 26     1770
# 27     1800
# 28     1819
# 29     1587
# 30     5604
# 31     1903
# 32     1894
# 33     2334
# 34     2061
# 35     2108
# 36     2149
# 37     2158
# 38     2213
# 39     3037
# 40     3416
# 41     7699
# 42     2200
# 43     2229
# 44     2128
# 45     2330
# 46     2248
# 47     2287
# 48     2316
# 49     9515
# Name: distance, dtype: int64

# %%
k=3
dataframe_filtered = dataframe_filtered.drop(['postalCode','city','country','name','categories','address','cc','crossStreet','formattedAddress','labeledLatLngs','state','id'],1)
kmeans = KMeans(n_clusters = k,random_state=0).fit(dataframe_filtered)
kmeans.labels_
dataframe_filtered.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
# create map
map_clusters = folium.Map(location=[19.0759899, 72.8773928],zoom_start=10)

# set color scheme for the clusters
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lng, neighbourhood, cluster in zip(dataframe_filtered['lat'], dataframe_filtered['lng'], dataframe_filtered['distance'], dataframe_filtered['Cluster Labels']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
As Mumbai is densly populated , We settle on 3 clusters , the central mumbai with red dotted are highly
