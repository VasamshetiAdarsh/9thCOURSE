# %% [markdown]
# ## Week 4 Project

# %%
# !pip install beautifulsoup4
# !pip install lxml
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 


from IPython.display import display_html
import pandas as pd
import numpy as np
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
from bs4 import BeautifulSoup
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors

print('Folium installed')
print('Libraries imported.')
# Out:
# Requirement already satisfied: beautifulsoup4 in /opt/conda/envs/Python36/lib/python3.6/site-packages (4.7.1)
# Requirement already satisfied: soupsieve>=1.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from beautifulsoup4) (1.7.1)
# Requirement already satisfied: lxml in /opt/conda/envs/Python36/lib/python3.6/site-packages (4.3.1)
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.6.20  |       hecda079_0         145 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     certifi-2020.6.20          |   py36h9f0ad1d_0         151 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          4.1.0-py_1        conda-forge
#     branca:          0.4.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     python_abi:      3.6-1_cp36m       conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     certifi:         2020.6.20-py36_0              --> 2020.6.20-py36h9f0ad1d_0 conda-forge
#     openssl:         1.1.1g-h7b6447c_0             --> 1.1.1g-h516909a_0        conda-forge
#
# The following packages will be DOWNGRADED:
#
#     ca-certificates: 2020.6.24-0                   --> 2020.6.20-hecda079_0     conda-forge
#
#
# Downloading and Extracting Packages
# ca-certificates-2020 | 145 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# certifi-2020.6.20    | 151 KB    | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %%
# Get longitude and latitude for Toronto
address = 'mumbai , mumbai'

geolocator = Nominatim(user_agent="mumbai_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of mumbai is {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of mumbai is 19.0759899, 72.8773928.

# %%
# Set up Foursquare
CLIENT_ID = 'W1T51HJBLTFBUZDEYA3KWJCSEVUMR5AKPD2SPO1WHZQH02TF' # your Foursquare ID
CLIENT_SECRET = 'JSFMQA04HEISC2P1CSEIQV1R5PES1WIWMDKKQ4KI02MGOIJ5' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: W1T51HJBLTFBUZDEYA3KWJCSEVUMR5AKPD2SPO1WHZQH02TF
# CLIENT_SECRET:JSFMQA04HEISC2P1CSEIQV1R5PES1WIWMDKKQ4KI02MGOIJ5

# %%
search_query = 'Restaurant'
radius = 50000
print(search_query + ' .... OK!')
# Out:
# Restaurant .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=W1T51HJBLTFBUZDEYA3KWJCSEVUMR5AKPD2SPO1WHZQH02TF&client_secret=JSFMQA04HEISC2P1CSEIQV1R5PES1WIWMDKKQ4KI02MGOIJ5&ll=19.0759899,72.8773928&v=20180605&query=Restaurant&radius=50000&limit=100'

# %%
results = requests.get(url).json()

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...    False
# 1  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...    False
# 2  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 3  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 4  [{'id': '54135bf5e4b08f3d2429dfe0', 'name': 'M...    False
#
#                          id  \
# 0  4d4be7dce1ec6dcb0874d275
# 1  4ffff479e4b0da072a4c510e
# 2  511776a6e4b0c785a054bc7b
# 3  4dc6a998b0fb5556cd0e99a2
# 4  5960987f5c6838397392b821
#
#                                     location.address location.cc  \
# 0                                                NaN          IN
# 1          Ostwal orbit,shop no 2\3,Kanakia junction          IN
# 2                                                NaN          IN
# 3                               Above Shoppers' Stop          IN
# 4  Ambika Darshan nxt to Neelkanth Corporate park...          IN
#
#   location.city location.country                 location.crossStreet  \
# 0        Mumbai            India                                  NaN
# 1        Mumbai            India                  Mira bhayandar road
# 2           NaN            India                                  NaN
# 3        Mumbai            India  Near Amar Mahal, Chembur- Ghatkopar
# 4        Mumbai            India                   kirol premier road
#
#    location.distance                          location.formattedAddress  \
# 0                820                       [Mumbai, Mahārāshtra, India]
# 1                 27  [Ostwal orbit,shop no 2\3,Kanakia junction (Mi...
# 2                 90                                            [India]
# 3               2534  [Above Shoppers' Stop (Near Amar Mahal, Chembu...
# 4               1887  [Ambika Darshan nxt to Neelkanth Corporate par...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 19.07463444538323...     19.074634
# 1  [{'label': 'display', 'lat': 19.0759837, 'lng'...     19.075984
# 2  [{'label': 'display', 'lat': 19.07670593261718...     19.076706
# 3  [{'label': 'display', 'lat': 19.06966328826220...     19.069663
# 4  [{'label': 'display', 'lat': 19.081892, 'lng':...     19.081892
#
#    location.lng location.postalCode location.state  \
# 0     72.869724                 NaN    Mahārāshtra
# 1     72.877656                 NaN    Mahārāshtra
# 2     72.877808                 NaN            NaN
# 3     72.900535              400089    Mahārāshtra
# 4     72.894210              400086    Mahārāshtra
#
#                                name    referralId venuePage.id
# 0           Mahesh Restaurant & Bar  v-1595525637          NaN
# 1                 Subway restaurant  v-1595525637          NaN
# 2          jhakas Family Restaurant  v-1595525637          NaN
# 3         IVY Restaurant & Banquets  v-1595525637     72795032
# 4  KYROS A Multi Cuisine Restaurant  v-1595525637          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                                name                      categories  \
# 0           Mahesh Restaurant & Bar                             Bar
# 1                 Subway restaurant                  Sandwich Place
# 2          jhakas Family Restaurant               Indian Restaurant
# 3         IVY Restaurant & Banquets                      Restaurant
# 4  KYROS A Multi Cuisine Restaurant  Multicuisine Indian Restaurant
#
#                                              address  cc    city country  \
# 0                                                NaN  IN  Mumbai   India
# 1          Ostwal orbit,shop no 2\3,Kanakia junction  IN  Mumbai   India
# 2                                                NaN  IN     NaN   India
# 3                               Above Shoppers' Stop  IN  Mumbai   India
# 4  Ambika Darshan nxt to Neelkanth Corporate park...  IN  Mumbai   India
#
#                            crossStreet  distance  \
# 0                                  NaN       820
# 1                  Mira bhayandar road        27
# 2                                  NaN        90
# 3  Near Amar Mahal, Chembur- Ghatkopar      2534
# 4                   kirol premier road      1887
#
#                                     formattedAddress  \
# 0                       [Mumbai, Mahārāshtra, India]
# 1  [Ostwal orbit,shop no 2\3,Kanakia junction (Mi...
# 2                                            [India]
# 3  [Above Shoppers' Stop (Near Amar Mahal, Chembu...
# 4  [Ambika Darshan nxt to Neelkanth Corporate par...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 19.07463444538323...  19.074634  72.869724
# 1  [{'label': 'display', 'lat': 19.0759837, 'lng'...  19.075984  72.877656
# 2  [{'label': 'display', 'lat': 19.07670593261718...  19.076706  72.877808
# 3  [{'label': 'display', 'lat': 19.06966328826220...  19.069663  72.900535
# 4  [{'label': 'display', 'lat': 19.081892, 'lng':...  19.081892  72.894210
#
#   postalCode        state                        id
# 0        NaN  Mahārāshtra  4d4be7dce1ec6dcb0874d275
# 1        NaN  Mahārāshtra  4ffff479e4b0da072a4c510e
# 2        NaN          NaN  511776a6e4b0c785a054bc7b
# 3     400089  Mahārāshtra  4dc6a998b0fb5556cd0e99a2
# 4     400086  Mahārāshtra  5960987f5c6838397392b821

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
search_query = 'Office'
radius = 50000
print(search_query + ' .... OK!')
# Out:
# Office .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=W1T51HJBLTFBUZDEYA3KWJCSEVUMR5AKPD2SPO1WHZQH02TF&client_secret=JSFMQA04HEISC2P1CSEIQV1R5PES1WIWMDKKQ4KI02MGOIJ5&ll=19.0759899,72.8773928&v=20180605&query=Office&radius=50000&limit=100'

# %%
results = requests.get(url).json()

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '5032764e91d4c4b30a586d5a', 'name': 'C...    False
# 1  [{'id': '4bf58dd8d48988d172941735', 'name': 'P...    False
# 2  [{'id': '4bf58dd8d48988d126941735', 'name': 'G...    False
# 3                                                 []    False
# 4  [{'id': '52f2ab2ebcbc57f1066b8b36', 'name': 'I...    False
#
#                          id location.address location.cc location.city  \
# 0  53a2ba15498e11c1732c81a3              NaN          IN           NaN
# 1  522ae27211d23abba41a0045              NaN          IN        Mumbai
# 2  5191c30e498ef53d154ea579              NaN          IN           NaN
# 3  4c36c4d70a71c9b60dc23dc9    Chandrapushpa          IN        Mumbai
# 4  5e40f662059d1f0008c4ae88              NaN          IN        Mumbai
#
#   location.country location.crossStreet  location.distance  \
# 0            India                  NaN                 27
# 1            India                  NaN                309
# 2            India                  NaN                614
# 3            India              HD Road               1666
# 4            India                  NaN               1005
#
#                            location.formattedAddress  \
# 0                                            [India]
# 1                       [Mumbai, Mahārāshtra, India]
# 2                                            [India]
# 3  [Chandrapushpa (HD Road), Mumbai 400086, Mahār...
# 4                [Mumbai 400013, Mahārāshtra, India]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 19.07598139540013...     19.075981
# 1  [{'label': 'display', 'lat': 19.07360458374023...     19.073605
# 2  [{'label': 'display', 'lat': 19.07084865356027...     19.070849
# 3  [{'label': 'display', 'lat': 19.068907, 'lng':...     19.068907
# 4  [{'label': 'display', 'lat': 19.08174876942108...     19.081749
#
#    location.lng location.postalCode location.state  \
# 0     72.877656                 NaN            NaN
# 1     72.875877                 NaN    Mahārāshtra
# 2     72.879520                 NaN            NaN
# 3     72.891345              400086    Mahārāshtra
# 4     72.884760              400013    Mahārāshtra
#
#                            name    referralId
# 0  Logitech office trade center  v-1595525644
# 1             Kurla Post Office  v-1595525644
# 2  "L" Ward Office, Kurla West.  v-1595525644
# 3                        Office  v-1595525644
# 4            Office Tips Tricks  v-1595525644

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                            name           categories        address  cc  \
# 0  Logitech office trade center      Campaign Office            NaN  IN
# 1             Kurla Post Office          Post Office            NaN  IN
# 2  "L" Ward Office, Kurla West.  Government Building            NaN  IN
# 3                        Office                 None  Chandrapushpa  IN
# 4            Office Tips Tricks          IT Services            NaN  IN
#
#      city country crossStreet  distance  \
# 0     NaN   India         NaN        27
# 1  Mumbai   India         NaN       309
# 2     NaN   India         NaN       614
# 3  Mumbai   India     HD Road      1666
# 4  Mumbai   India         NaN      1005
#
#                                     formattedAddress  \
# 0                                            [India]
# 1                       [Mumbai, Mahārāshtra, India]
# 2                                            [India]
# 3  [Chandrapushpa (HD Road), Mumbai 400086, Mahār...
# 4                [Mumbai 400013, Mahārāshtra, India]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 19.07598139540013...  19.075981  72.877656
# 1  [{'label': 'display', 'lat': 19.07360458374023...  19.073605  72.875877
# 2  [{'label': 'display', 'lat': 19.07084865356027...  19.070849  72.879520
# 3  [{'label': 'display', 'lat': 19.068907, 'lng':...  19.068907  72.891345
# 4  [{'label': 'display', 'lat': 19.08174876942108...  19.081749  72.884760
#
#   postalCode        state                        id
# 0        NaN          NaN  53a2ba15498e11c1732c81a3
# 1        NaN  Mahārāshtra  522ae27211d23abba41a0045
# 2        NaN          NaN  5191c30e498ef53d154ea579
# 3     400086  Mahārāshtra  4c36c4d70a71c9b60dc23dc9
# 4     400013  Mahārāshtra  5e40f662059d1f0008c4ae88

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=14
                       ) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='orange',
        popup=label,
        fill = True,
        fill_color='orange',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
dataframe_filtered.shape
# Out:
# (50, 15)

# %%
dataframe_filtered.dtypes
# Out:
# name                 object
# categories           object
# address              object
# cc                   object
# city                 object
# country              object
# crossStreet          object
# distance              int64
# formattedAddress     object
# labeledLatLngs       object
# lat                 float64
# lng                 float64
# postalCode           object
# state                object
# id                   object
# dtype: object
